# %% [markdown]
# <a href="https://colab.research.google.com/github/V-Nayak/SQL-Assignments/blob/main/Data_Def_Language(DDL).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Page 1**
# ![1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Page 2**
# ![2.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Page 3**
# ![3.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Page 4**
# ![4.jpeg](data:image/jpeg;base64,...)
