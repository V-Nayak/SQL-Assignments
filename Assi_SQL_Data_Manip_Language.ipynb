# %% [markdown]
# <a href="https://colab.research.google.com/github/V-Nayak/SQL-Assignments/blob/main/Assi_SQL_Data_Manip_Language.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Page 1**
# ![WhatsApp Image 2022-06-02 at 10.24.58 AM (2).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Page 2**
# ![WhatsApp Image 2022-06-02 at 10.24.58 AM (1).jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Page 3**
# ![WhatsApp Image 2022-06-02 at 10.24.58 AM.jpeg](data:image/jpeg;base64,...)**

# %% [markdown]
# # **Page 4**
# ![WhatsApp Image 2022-06-02 at 10.24.59 AM.jpeg](data:image/jpeg;base64,...)
